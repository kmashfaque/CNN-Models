# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Flatten
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.applications import MobileNetV2
from keras.applications import EfficientNetB0
from keras.applications import ResNet50
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers.schedules import ExponentialDecay
import keras_tuner as kt
from sklearn.metrics import roc_auc_score, confusion_matrix
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import keras_tuner as kt
import os
import numpy as np
# Out:
# 2025-07-19 15:28:53.729346: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752938933.941113      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752938934.000519      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
conv_base = EfficientNetB0(
    weights='imagenet',
    include_top = False,
    input_shape=(224,224,3)
)
# Out:
# I0000 00:00:1752938947.972656      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1752938947.973273      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
lr_schedule = ExponentialDecay(
    initial_learning_rate=1e-4,
    decay_steps=1000,
    decay_rate=0.9,
)
optimizer = keras.optimizers.Adam(learning_rate=lr_schedule)

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,  # Reduce learning rate by a factor of 0.2
    patience=3,  # Wait 3 epochs before reducing
    min_lr=1e-6  # Minimum learning rate
)

# %%
# Define data augmentation
data_augmentation = keras.Sequential([
    # layers.RandomZoom(0.2),
    # layers.RandomTranslation(0.2, 0.2),
    # layers.RandomContrast(0.2),
    # layers.RandomBrightness(0.2),
    layers.RandomFlip("horizontal"),
    layers.RandomFlip("vertical"),
    layers.RandomRotation(0.3),
])

# %%
# Load dataset from input/fold
dataset_path = "/kaggle/input/refined-model-data/dataset_1/preprocessed_original_images/"
# dataset_path = "/kaggle/input/refined-model-data/dataset_2/"
img_height = 224
img_width = 224
batch_size = 20

dataset = keras.utils.image_dataset_from_directory(
    directory=dataset_path,
    labels='inferred',
    label_mode='int',
    batch_size=batch_size,
    image_size=(img_height, img_width),
    shuffle=True
)
# Out:
# Found 847 files belonging to 6 classes.

# %%
# Split dataset into train (80%) and test (20%)
dataset_size = tf.data.experimental.cardinality(dataset).numpy()
train_size = int(0.8 * dataset_size)
test_size = dataset_size - train_size

train_dataset = dataset.take(train_size)
test_dataset = dataset.skip(train_size)

# Further split train_dataset into train (80%) and validation (20%)
val_size = int(0.2 * train_size)
train_dataset = train_dataset.skip(val_size)
val_dataset = train_dataset.take(val_size)

# %%
# Function to apply augmentation and normalization to training data
def process_train(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0,1]
    image = data_augmentation(image)            # Apply augmentation
    return image, label

# Function to normalize validation and test data
def process_val(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0,1]
    return image, label

# %%
# Apply processing functions
train_dataset = train_dataset.map(process_train, num_parallel_calls=tf.data.AUTOTUNE)
val_dataset = val_dataset.map(process_val, num_parallel_calls=tf.data.AUTOTUNE)
test_dataset = test_dataset.map(process_val, num_parallel_calls=tf.data.AUTOTUNE)

# Prefetch for performance
train_dataset = train_dataset.cache().shuffle(1000).prefetch(tf.data.AUTOTUNE)
val_dataset = val_dataset.cache().prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.cache().prefetch(tf.data.AUTOTUNE)

# %%
# # Load VGG16 base model
# conv_base = keras.applications.VGG16(
#     weights='imagenet', 
#     include_top=False, 
#     input_shape=(224, 224, 3))

# %%
# # Unfreeze top 30 layers
for layer in conv_base.layers[-20:]:
    layer.trainable = True

# %%
# Define model-building function for Keras Tuner
def build_model(hp):
    # inputs = keras.Input(shape=(224, 224, 3))
    # x = data_augmentation(inputs)
    # x = conv_base(x, training=False)
    # x = layers.GlobalAveragePooling2D()(x)
    # x = layers.Dense(256, activation='relu')(x)
    # x = layers.Dropout(0.3)(x)
    # outputs = layers.Dense(6, activation='softmax')(x)
    # model = keras.Model(inputs, outputs)
    # model.compile(
    #     optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    #     loss='sparse_categorical_crossentropy',
    #     metrics=['accuracy']
    # )

    
    model = keras.Sequential()
    model.add(conv_base)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dense(
        units=hp.Int('units', min_value=128, max_value=512, step=128),
        activation='relu'
    ))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(6, activation='softmax'))  # 4 classes
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Float('learning_rate', 1e-5, 1e-1, sampling='log')
        ),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
# Initialize Keras Tuner
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    directory='tuner_dir_efficientnet_data_1',
    project_name='efficientnet_classification_data_2'
)
# Search for best hyperparameters
tuner.search(
    train_dataset,
    validation_data=val_dataset,
    epochs=10,
    # class_weight=class_weights
)
# Out:
# Trial 10 Complete [00h 02m 06s]
# val_accuracy: 0.6666666865348816
#
# Best val_accuracy So Far: 0.7666666507720947
# Total elapsed time: 00h 20m 16s

# %%
# Get the best model
best_model = tuner.get_best_models(num_models=1)[0]

# Get best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Best units: {best_hps.get('units')}")
print(f"Best learning rate: {best_hps.get('learning_rate')}")

# Create output directory
output_dir = 'efficientnet/'
os.makedirs(output_dir, exist_ok=True)
# Out:
# Best units: 512
# Best learning rate: 1.0278521873057983e-05
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 432 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Save the best model and weights
best_model.save(os.path.join(output_dir, 'best_model.keras'))
best_model.save_weights(os.path.join(output_dir, 'best_model_weights.weights.h5'))

# Define callbacks for further training
checkpoint = keras.callbacks.ModelCheckpoint(
    os.path.join(output_dir, 'best_finetuned_model.keras'),
    monitor='val_accuracy',
    save_best_only=True,
    mode='max'
)

# %%
# Further train the best model
history = best_model.fit(
    train_dataset,
    epochs=100,
    validation_data=val_dataset,
    # class_weight=class_weights,
    # callbacks=[checkpoint]
)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 90s 429ms/step - accuracy: 1.0000 - loss: 0.1871 - val_accuracy: 0.7500 - val_loss: 0.8611
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.1474 - val_accuracy: 0.7583 - val_loss: 0.8200
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.1101 - val_accuracy: 0.7667 - val_loss: 0.8182
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0729 - val_accuracy: 0.7667 - val_loss: 0.8194
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 1.0000 - loss: 0.0660 - val_accuracy: 0.7583 - val_loss: 0.8210
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 1.0000 - loss: 0.0591 - val_accuracy: 0.7667 - val_loss: 0.8059
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 1.0000 - loss: 0.0468 - val_accuracy: 0.7583 - val_loss: 0.7999
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 1.0000 - loss: 0.0439 - val_accuracy: 0.7583 - val_loss: 0.8107
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 1.0000 - loss: 0.0327 - val_accuracy: 0.7750 - val_loss: 0.8043
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 1.0000 - loss: 0.0318 - val_accuracy: 0.7750 - val_loss: 0.8087
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 1.0000 - loss: 0.0269 - val_accuracy: 0.7750 - val_loss: 0.8096
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 1.0000 - loss: 0.0230 - val_accuracy: 0.7750 - val_loss: 0.8087
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 1.0000 - loss: 0.0206 - val_accuracy: 0.7750 - val_loss: 0.8152
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 1.0000 - loss: 0.0213 - val_accuracy: 0.7917 - val_loss: 0.8214
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 0.7833 - val_loss: 0.8181
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.7833 - val_loss: 0.8207
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.7750 - val_loss: 0.8165
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.9988 - loss: 0.0145 - val_accuracy: 0.7750 - val_loss: 0.9318
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.7750 - val_loss: 0.9521
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.9990 - loss: 0.0152 - val_accuracy: 0.8000 - val_loss: 0.9593
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.8000 - val_loss: 0.9386
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.7917 - val_loss: 0.9141
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.7833 - val_loss: 0.8919
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.7833 - val_loss: 0.8739
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.7833 - val_loss: 0.8851
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.7833 - val_loss: 0.8802
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.7833 - val_loss: 0.8855
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.7750 - val_loss: 0.8897
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.7750 - val_loss: 0.8907
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.7750 - val_loss: 0.9018
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.7750 - val_loss: 0.9106
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.7833 - val_loss: 0.9257
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.7750 - val_loss: 0.9471
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.7667 - val_loss: 0.9589
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.7667 - val_loss: 0.9487
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.7667 - val_loss: 0.9367
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.7667 - val_loss: 0.9480
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.7667 - val_loss: 0.9739
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.7667 - val_loss: 0.9748
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.7917 - val_loss: 0.9637
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.7833 - val_loss: 0.9478
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.7917 - val_loss: 0.9551
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.7750 - val_loss: 0.9150
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.7750 - val_loss: 0.9225
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.7667 - val_loss: 0.9166
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.7750 - val_loss: 0.9181
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.7750 - val_loss: 0.9259
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.7833 - val_loss: 0.9348
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.7833 - val_loss: 0.9487
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.7750 - val_loss: 0.9517
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.7750 - val_loss: 0.9778
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.7750 - val_loss: 1.0096
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.7833 - val_loss: 0.9999
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.7833 - val_loss: 1.0004
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.7833 - val_loss: 1.0776
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.7750 - val_loss: 1.0489
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.7750 - val_loss: 1.0286
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7750 - val_loss: 1.0364
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.7833 - val_loss: 1.0281
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.7750 - val_loss: 1.0041
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7750 - val_loss: 1.0115
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7833 - val_loss: 1.0247
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7833 - val_loss: 1.0319
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.7750 - val_loss: 1.0169
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7833 - val_loss: 1.0200
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.7833 - val_loss: 1.0135
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.7917 - val_loss: 1.0371
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.7833 - val_loss: 1.0304
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.7750 - val_loss: 1.0308
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8000 - val_loss: 0.9931
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8000 - val_loss: 0.9962
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7833 - val_loss: 1.0412
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.7833 - val_loss: 1.0484
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.7750 - val_loss: 1.0605
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.7833 - val_loss: 1.0734
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.7750 - val_loss: 1.1338
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 9.6928e-04 - val_accuracy: 0.7667 - val_loss: 1.1631
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.7667 - val_loss: 1.1587
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.7667 - val_loss: 1.1357
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.7833 - val_loss: 1.0830
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 9.2360e-04 - val_accuracy: 0.7833 - val_loss: 1.0583
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 8.9116e-04 - val_accuracy: 0.7833 - val_loss: 1.0358
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 9.5412e-04 - val_accuracy: 0.7833 - val_loss: 1.0358
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 7.7259e-04 - val_accuracy: 0.7750 - val_loss: 1.0441
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 8.4778e-04 - val_accuracy: 0.7750 - val_loss: 1.0553
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.7833 - val_loss: 1.0588
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 7.9732e-04 - val_accuracy: 0.7750 - val_loss: 1.0707
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.7750 - val_loss: 1.0636
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 6.4858e-04 - val_accuracy: 0.7750 - val_loss: 1.0577
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.7750 - val_loss: 1.0368
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 1.0000 - loss: 6.9785e-04 - val_accuracy: 0.7833 - val_loss: 1.0330
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.7750 - val_loss: 1.0436
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 7.1147e-04 - val_accuracy: 0.7750 - val_loss: 1.0556
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 5.5629e-04 - val_accuracy: 0.7750 - val_loss: 1.0586
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 8.4845e-04 - val_accuracy: 0.7833 - val_loss: 1.0746
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 6.6767e-04 - val_accuracy: 0.7833 - val_loss: 1.0745
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 7.7817e-04 - val_accuracy: 0.7833 - val_loss: 1.0718
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 6.9320e-04 - val_accuracy: 0.7833 - val_loss: 1.0767
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 4.5450e-04 - val_accuracy: 0.7667 - val_loss: 1.0854
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 5.7033e-04 - val_accuracy: 0.7750 - val_loss: 1.0907

# %%
# Evaluate the model on test dataset
loss, accuracy = best_model.evaluate(test_dataset)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 609ms/step - accuracy: 0.8288 - loss: 0.7958
# Test Loss: 0.7781
# Test Accuracy: 0.8443

# %%
import matplotlib.pyplot as plt
# Plot training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Epoch vs Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
# plt.savefig('/kaggle/working/resnet/accuracy_plot.png')
plt.show()

# %%
best_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │         3,078 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,041,519 (53.56 MB)
#  Trainable params: 4,666,498 (17.80 MB)
#  Non-trainable params: 42,023 (164.16 KB)
#  Optimizer params: 9,332,998 (35.60 MB)

# %%
dataset.class_names
# Out:
# ['chickenpox', 'cowpox', 'healthy', 'measles', 'monkeypox', 'smallpox']

# %%
# --- Evaluation Metrics ---
# Collect true labels and predictions from the test dataset
from sklearn.metrics import classification_report

y_true = []
y_pred = []
y_pred_proba = []
class_names=dataset.class_names

for images, labels in test_dataset.unbatch():
    y_true.append(labels.numpy())
    predictions = best_model.predict(images[None, ...], verbose=0)
    y_pred.append(np.argmax(predictions, axis=1)[0])
    y_pred_proba.append(predictions[0])

y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_pred_proba = np.array(y_pred_proba)

# 1. Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#   chickenpox       0.84      0.84      0.84        43
#       cowpox       1.00      0.82      0.90        11
#      healthy       1.00      1.00      1.00         9
#      measles       0.50      0.17      0.25         6
#    monkeypox       0.83      0.76      0.79        33
#     smallpox       0.82      0.94      0.88        65
#
#     accuracy                           0.84       167
#    macro avg       0.83      0.75      0.78       167
# weighted avg       0.84      0.84      0.84       167

# %%
# 2. Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Plot training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
# Plot training and validation accuracy
plt.figure(figsize=(5, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Epoch vs Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
plt.savefig('/kaggle/working/efficientnet/accuracy_plot.png')
plt.show()
