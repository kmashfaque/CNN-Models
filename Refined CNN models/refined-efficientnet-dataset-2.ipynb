# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Flatten
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.applications import MobileNetV2
from keras.applications import EfficientNetB0
from keras.applications import ResNet50
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers.schedules import ExponentialDecay
import keras_tuner as kt
from sklearn.metrics import roc_auc_score, confusion_matrix
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import keras_tuner as kt
import os
import numpy as np

# %%
conv_base = EfficientNetB0(
    weights='imagenet',
    include_top = False,
    input_shape=(224,224,3)
)

# %%
lr_schedule = ExponentialDecay(
    initial_learning_rate=1e-4,
    decay_steps=1000,
    decay_rate=0.9,
)
optimizer = keras.optimizers.Adam(learning_rate=lr_schedule)

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,  # Reduce learning rate by a factor of 0.2
    patience=3,  # Wait 3 epochs before reducing
    min_lr=1e-6  # Minimum learning rate
)

# %%
# Define data augmentation
data_augmentation = keras.Sequential([
    # layers.RandomZoom(0.2),
    # layers.RandomTranslation(0.2, 0.2),
    # layers.RandomContrast(0.2),
    # layers.RandomBrightness(0.2),
    layers.RandomFlip("horizontal"),
    layers.RandomFlip("vertical"),
    layers.RandomRotation(0.3),
])

# %%
# Load dataset from input/fold
# dataset_path = "/kaggle/input/refined-model-data/dataset_1/preprocessed_original_images/"
dataset_path = "/kaggle/input/refined-model-data/dataset_2/"
img_height = 224
img_width = 224
batch_size = 20

dataset = keras.utils.image_dataset_from_directory(
    directory=dataset_path,
    labels='inferred',
    label_mode='int',
    batch_size=batch_size,
    image_size=(img_height, img_width),
    shuffle=True
)
# Out:
# Found 659 files belonging to 4 classes.

# %%
# Split dataset into train (80%) and test (20%)
dataset_size = tf.data.experimental.cardinality(dataset).numpy()
train_size = int(0.8 * dataset_size)
test_size = dataset_size - train_size

train_dataset = dataset.take(train_size)
test_dataset = dataset.skip(train_size)

# Further split train_dataset into train (80%) and validation (20%)
val_size = int(0.2 * train_size)
train_dataset = train_dataset.skip(val_size)
val_dataset = train_dataset.take(val_size)

# %%
# Function to apply augmentation and normalization to training data
def process_train(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0,1]
    image = data_augmentation(image)            # Apply augmentation
    return image, label

# Function to normalize validation and test data
def process_val(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0,1]
    return image, label

# %%
# Apply processing functions
train_dataset = train_dataset.map(process_train, num_parallel_calls=tf.data.AUTOTUNE)
val_dataset = val_dataset.map(process_val, num_parallel_calls=tf.data.AUTOTUNE)
test_dataset = test_dataset.map(process_val, num_parallel_calls=tf.data.AUTOTUNE)

# Prefetch for performance
train_dataset = train_dataset.cache().shuffle(1000).prefetch(tf.data.AUTOTUNE)
val_dataset = val_dataset.cache().prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.cache().prefetch(tf.data.AUTOTUNE)

# %%
# # Load VGG16 base model
# conv_base = keras.applications.VGG16(
#     weights='imagenet', 
#     include_top=False, 
#     input_shape=(224, 224, 3))

# %%
# # Unfreeze top 30 layers
for layer in conv_base.layers[-20:]:
    layer.trainable = True

# %%
# Define model-building function for Keras Tuner
def build_model(hp):
    # inputs = keras.Input(shape=(224, 224, 3))
    # x = data_augmentation(inputs)
    # x = conv_base(x, training=False)
    # x = layers.GlobalAveragePooling2D()(x)
    # x = layers.Dense(256, activation='relu')(x)
    # x = layers.Dropout(0.3)(x)
    # outputs = layers.Dense(6, activation='softmax')(x)
    # model = keras.Model(inputs, outputs)
    # model.compile(
    #     optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    #     loss='sparse_categorical_crossentropy',
    #     metrics=['accuracy']
    # )

    
    model = keras.Sequential()
    model.add(conv_base)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dense(
        units=hp.Int('units', min_value=128, max_value=512, step=128),
        activation='relu'
    ))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(6, activation='softmax'))  # 4 classes
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Float('learning_rate', 1e-5, 1e-1, sampling='log')
        ),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
# Initialize Keras Tuner
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    directory='tuner_dir_efficientnet_data_2',
    project_name='efficientnet_classification_data_1'
)
# Search for best hyperparameters
tuner.search(
    train_dataset,
    validation_data=val_dataset,
    epochs=10,
    # class_weight=class_weights
)
# Out:
# Trial 10 Complete [00h 02m 09s]
# val_accuracy: 0.3799999952316284
#
# Best val_accuracy So Far: 0.8299999833106995
# Total elapsed time: 00h 20m 53s

# %%
# Get the best model
best_model = tuner.get_best_models(num_models=1)[0]

# Get best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Best units: {best_hps.get('units')}")
print(f"Best learning rate: {best_hps.get('learning_rate')}")

# Create output directory
output_dir = 'efficientnet_data2/'
os.makedirs(output_dir, exist_ok=True)
# Out:
# Best units: 512
# Best learning rate: 5.2777474560786534e-05
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 432 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Save the best model and weights
best_model.save(os.path.join(output_dir, 'best_model.keras'))
best_model.save_weights(os.path.join(output_dir, 'best_model_weights.weights.h5'))

# Define callbacks for further training
checkpoint = keras.callbacks.ModelCheckpoint(
    os.path.join(output_dir, 'best_finetuned_model.keras'),
    monitor='val_accuracy',
    save_best_only=True,
    mode='max'
)

# %%
# Further train the best model
history = best_model.fit(
    train_dataset,
    epochs=100,
    validation_data=val_dataset,
    # class_weight=class_weights,
    # callbacks=[checkpoint]
)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 101s 633ms/step - accuracy: 0.9996 - loss: 0.0121 - val_accuracy: 0.4000 - val_loss: 1.7052
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.3900 - val_loss: 1.5691
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.5800 - val_loss: 1.2279
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.9963 - loss: 0.0044 - val_accuracy: 0.8300 - val_loss: 0.6666
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8200 - val_loss: 0.7016
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 1.0000 - loss: 6.4190e-04 - val_accuracy: 0.7800 - val_loss: 0.6307
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.8100 - val_loss: 0.8590
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 1.0000 - loss: 8.6072e-04 - val_accuracy: 0.2500 - val_loss: 3.9752
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 1.0000 - loss: 9.3887e-04 - val_accuracy: 0.2300 - val_loss: 2.8799
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 1.0000 - loss: 8.8284e-04 - val_accuracy: 0.2800 - val_loss: 8.7586
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 1.0000 - loss: 3.5969e-04 - val_accuracy: 0.3400 - val_loss: 3.9857
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.6700 - val_loss: 1.1481
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9978 - loss: 0.0045 - val_accuracy: 0.5500 - val_loss: 1.3327
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 1.0000 - loss: 3.8489e-04 - val_accuracy: 0.5500 - val_loss: 1.6972
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.9985 - loss: 0.0018 - val_accuracy: 0.4100 - val_loss: 1.8767
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 1.0000 - loss: 6.4253e-04 - val_accuracy: 0.4100 - val_loss: 1.6450
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6600 - val_loss: 1.0064
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 7.7905e-04 - val_accuracy: 0.6300 - val_loss: 1.2234
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6400 - val_loss: 1.0367
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 2.3501e-04 - val_accuracy: 0.6100 - val_loss: 1.0074
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 4.9588e-04 - val_accuracy: 0.7300 - val_loss: 0.8925
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 2.8622e-04 - val_accuracy: 0.7200 - val_loss: 0.8501
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 1.2983e-04 - val_accuracy: 0.7400 - val_loss: 0.7760
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8400 - val_loss: 0.8273
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 4.3984e-04 - val_accuracy: 0.8500 - val_loss: 0.6221
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 1.0000 - loss: 9.1904e-05 - val_accuracy: 0.8500 - val_loss: 0.5818
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 1.0000 - loss: 1.2587e-04 - val_accuracy: 0.8400 - val_loss: 0.5629
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.9987 - loss: 0.0030 - val_accuracy: 0.1700 - val_loss: 2.3437
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.9950 - loss: 0.0103 - val_accuracy: 0.3700 - val_loss: 473.3266
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 1.0000 - loss: 5.2008e-04 - val_accuracy: 0.3200 - val_loss: 73.1373
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 1.0000 - loss: 9.1246e-04 - val_accuracy: 0.2300 - val_loss: 6.9844
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 1.0000 - loss: 2.1595e-04 - val_accuracy: 0.2000 - val_loss: 2.3321
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 1.0000 - loss: 2.4401e-04 - val_accuracy: 0.2200 - val_loss: 1.9187
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 1.0000 - loss: 7.6001e-04 - val_accuracy: 0.3700 - val_loss: 1.9907
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.5100 - val_loss: 1.3414
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.9940 - loss: 0.0069 - val_accuracy: 0.6300 - val_loss: 1.2006
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.9980 - loss: 0.0070 - val_accuracy: 0.1500 - val_loss: 2.5874
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 8.4412e-04 - val_accuracy: 0.2100 - val_loss: 2.6566
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 6.0318e-04 - val_accuracy: 0.3400 - val_loss: 1.9141
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 3.0581e-04 - val_accuracy: 0.4400 - val_loss: 1.9970
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.4000 - val_loss: 1.9241
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.9975 - loss: 0.0032 - val_accuracy: 0.1800 - val_loss: 3.1533
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.1600 - val_loss: 2.6482
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.2300 - val_loss: 2.5762
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.5700 - val_loss: 1.4683
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 1.3049e-04 - val_accuracy: 0.6600 - val_loss: 1.0400
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 3.4766e-04 - val_accuracy: 0.7400 - val_loss: 0.8951
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 1.1959e-04 - val_accuracy: 0.7600 - val_loss: 0.9600
# Epoch 49/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 1.0000 - loss: 2.6674e-04 - val_accuracy: 0.8200 - val_loss: 0.7422
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 1.0000 - loss: 1.1271e-04 - val_accuracy: 0.8300 - val_loss: 0.6621
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 1.0000 - loss: 9.3216e-05 - val_accuracy: 0.8400 - val_loss: 0.6622
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 1.0000 - loss: 1.3759e-04 - val_accuracy: 0.8400 - val_loss: 0.6393
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 1.0000 - loss: 2.5214e-04 - val_accuracy: 0.8500 - val_loss: 0.6730
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 1.0000 - loss: 1.8892e-04 - val_accuracy: 0.8700 - val_loss: 0.6627
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 1.0000 - loss: 3.9846e-04 - val_accuracy: 0.8500 - val_loss: 0.5871
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 1.0000 - loss: 8.6369e-05 - val_accuracy: 0.8800 - val_loss: 0.5889
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 5.9507e-05 - val_accuracy: 0.8900 - val_loss: 0.5466
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 5.9672e-05 - val_accuracy: 0.8700 - val_loss: 0.6330
# Epoch 59/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 1.4250e-04 - val_accuracy: 0.8700 - val_loss: 0.6830
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 1.5170e-04 - val_accuracy: 0.9000 - val_loss: 0.5132
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 6.5100e-05 - val_accuracy: 0.8900 - val_loss: 0.5678
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 5.4253e-05 - val_accuracy: 0.8800 - val_loss: 0.6674
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 3.2758e-05 - val_accuracy: 0.8900 - val_loss: 0.6659
# Epoch 64/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.9914 - loss: 0.0499 - val_accuracy: 0.4200 - val_loss: 1703.1937
# Epoch 65/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.9985 - loss: 0.0028 - val_accuracy: 0.3800 - val_loss: 2408.9082
# Epoch 66/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.9975 - loss: 0.0113 - val_accuracy: 0.3800 - val_loss: 2850.8081
# Epoch 67/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 8.8644e-04 - val_accuracy: 0.3700 - val_loss: 1425.9988
# Epoch 68/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 1.2463e-04 - val_accuracy: 0.3800 - val_loss: 905.7207
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.9963 - loss: 0.0141 - val_accuracy: 0.3600 - val_loss: 150.9562
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.3200 - val_loss: 3.0996
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.9958 - loss: 0.0175 - val_accuracy: 0.5000 - val_loss: 1.3875
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 4.6934e-04 - val_accuracy: 0.6300 - val_loss: 1.0995
# Epoch 73/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 3.9126e-04 - val_accuracy: 0.7200 - val_loss: 0.9143
# Epoch 74/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 1.4146e-04 - val_accuracy: 0.7700 - val_loss: 0.8291
# Epoch 75/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 9.3095e-05 - val_accuracy: 0.8000 - val_loss: 0.7719
# Epoch 76/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 5.8529e-05 - val_accuracy: 0.8000 - val_loss: 0.7345
# Epoch 77/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 1.8737e-04 - val_accuracy: 0.8300 - val_loss: 0.6762
# Epoch 78/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8200 - val_loss: 0.8552
# Epoch 79/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 1.1255e-04 - val_accuracy: 0.7900 - val_loss: 0.8771
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 9.7163e-05 - val_accuracy: 0.8100 - val_loss: 0.8816
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 6.6580e-05 - val_accuracy: 0.8100 - val_loss: 0.8416
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8100 - val_loss: 0.8941
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.9991 - loss: 0.0011 - val_accuracy: 0.8000 - val_loss: 1.2334
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.9993 - loss: 0.0026 - val_accuracy: 0.3900 - val_loss: 1.8631
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 1.5719e-04 - val_accuracy: 0.3600 - val_loss: 175.2402
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 4.4842e-04 - val_accuracy: 0.3600 - val_loss: 3.5391
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 4.7699e-04 - val_accuracy: 0.2700 - val_loss: 2.0774
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 3.2707e-04 - val_accuracy: 0.3200 - val_loss: 1.9743
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 1.5952e-04 - val_accuracy: 0.4000 - val_loss: 1.7044
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 6.8068e-04 - val_accuracy: 0.6300 - val_loss: 1.2273
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 1.8273e-04 - val_accuracy: 0.6300 - val_loss: 1.1321
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 1.4489e-04 - val_accuracy: 0.7000 - val_loss: 0.9224
# Epoch 93/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 6.1490e-04 - val_accuracy: 0.6800 - val_loss: 0.9743
# Epoch 94/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 7.6866e-05 - val_accuracy: 0.7100 - val_loss: 0.9492
# Epoch 95/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 5.0754e-05 - val_accuracy: 0.7300 - val_loss: 0.8635
# Epoch 96/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 1.0000 - loss: 9.8073e-04 - val_accuracy: 0.6700 - val_loss: 1.2578
# Epoch 97/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 8.5559e-05 - val_accuracy: 0.5500 - val_loss: 1.7156
# Epoch 98/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 1.6600e-04 - val_accuracy: 0.6300 - val_loss: 1.5564
# Epoch 99/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 5.5860e-05 - val_accuracy: 0.6900 - val_loss: 1.2421
# Epoch 100/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 1.0000 - loss: 1.9449e-04 - val_accuracy: 0.7700 - val_loss: 1.0843

# %%
# Evaluate the model on test dataset
loss, accuracy = best_model.evaluate(test_dataset)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6789 - loss: 1.4982
# Test Loss: 1.5727
# Test Accuracy: 0.6835

# %%
import matplotlib.pyplot as plt
# Plot training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Epoch vs Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
# plt.savefig('/kaggle/working/resnet/accuracy_plot.png')
plt.show()

# %%
best_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │         3,078 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,041,519 (53.56 MB)
#  Trainable params: 4,666,498 (17.80 MB)
#  Non-trainable params: 42,023 (164.16 KB)
#  Optimizer params: 9,332,998 (35.60 MB)

# %%
dataset.class_names
# Out:
# ['Chickenpox', 'Measles', 'Monkeypox', 'Normal']

# %%
# --- Evaluation Metrics ---
# Collect true labels and predictions from the test dataset
from sklearn.metrics import classification_report

y_true = []
y_pred = []
y_pred_proba = []
class_names=dataset.class_names

for images, labels in test_dataset.unbatch():
    y_true.append(labels.numpy())
    predictions = best_model.predict(images[None, ...], verbose=0)
    y_pred.append(np.argmax(predictions, axis=1)[0])
    y_pred_proba.append(predictions[0])

y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_pred_proba = np.array(y_pred_proba)

# 1. Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#   Chickenpox       0.37      0.37      0.37        19
#      Measles       1.00      0.21      0.35        19
#    Monkeypox       0.81      0.75      0.78        64
#       Normal       0.63      0.97      0.77        37
#
#     accuracy                           0.68       139
#    macro avg       0.70      0.58      0.57       139
# weighted avg       0.73      0.68      0.66       139

# %%
# 2. Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Plot training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
# Plot training and validation accuracy
plt.figure(figsize=(5, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Epoch vs Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
plt.savefig('/kaggle/working/efficientnet_data2/accuracy_plot.png')
plt.show()
